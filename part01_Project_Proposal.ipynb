# %% [markdown]
# # Project Title
#
# # Flower Species Classification Using Deep Learning with PyTorch
#
# Zhixi Ye

# %% [markdown]
# FlowerClassificationProject/
# │
# ├── dataset/
# │
# ├── notebooks/
# │   │
# │   ├── Part01_Project_Proposal.ipynb
# │   ├── Part02_Dataset.ipynb
# │   ├── Part03_EDA.ipynb
# │   ├── Part04_Preprocessing.ipynb
# │   ├── Part05_CNN.ipynb
# │   ├── Part06_ResNet18.ipynb
# │   ├── Part07_EfficientNet.ipynb
# │   ├── Part08_ModelComparison.ipynb
# │   ├── Part09_GradCAM.ipynb
# │   └── Part10_GUI.ipynb
# │
# ├── models/
# │   ├── cnn.py
# │   ├── resnet18.py
# │   └── efficientnet.py
# │
# ├── utils/
# │   ├── flower_names.py
# │   ├── dataset.py
# │   ├── metrics.py
# │   ├── visualization.py
# │   └── transforms.py
# │
# ├── weights/
# │
# ├── results/
# │
# ├── app/
# │   └── app.py
# │
# ├── train.py
# ├── predict.py
# ├── requirements.txt
# └── README.md
